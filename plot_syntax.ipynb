# %%
import numpy as np 
import pickle 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
sns.set_style("darkgrid")
BLACK = "k"
GREEN = "#59d98e"
SEA = "#159d82"
BLUE = "#3498db"
PURPLE = "#9b59b6"
GREY = "#95a5a6"
RED = "#e74c3c"
ORANGE = "#f39c12"
YELLOW = "#f1c40f"
GRAY = "#95a5a6"
BROWN = "#8e44ad"
CYAN = "#8e44ad"

def get_data_points(head_data):
  xs, ys, avgs = [], [], []
  for layer in range(12):
    for head in range(12):
      ys.append(head_data[layer][head])
      xs.append(1 + layer)
    avgs.append(head_data[layer].mean())
  return xs, ys, avgs

def add_line(key, ax, color, label, plot_avgs=True):
  xs, ys, avgs = get_data_points(avg_attns[key])
  ax.scatter(xs, ys, s=12, label=label, color=color)
  if plot_avgs:
    ax.plot(1 + np.arange(len(avgs)), avgs, color=color)
  ax.legend(loc="best")
  ax.set_xlabel("Layer")
  ax.set_ylabel("Avg. Attention")

# %%
syntax_list = ['annotation', 'basictype', 'boolean', 
                    'decimalinteger', 'identifier', 'keyword',
                    'modifier', 'operator', 'separator', 'null',
                    'string', 'decimalfloatingpoint']

# %%
CD = pickle.load(open("/Users/jirigesi/Desktop/base_results/base_results/CD_Syntax_avg.pkl", "rb"))
DD4CD = pickle.load(open("/Users/jirigesi/Desktop/order_results/DD4CD_Syntax_avg.pkl", "rb"))

# %%
avg_attns = {}
a = list(DD4CD.keys())
for key in a:
    avg_attns[key+'_CD'] = CD[key]
    avg_attns[key+'_DD4CD'] = DD4CD[key]

# %%
plt.figure(figsize=(6, 16))
ax = plt.subplot(4, 1, 1)
for key, color, label in [ ("identifier_CD", BLUE, "identifier_CD"),
                           ("identifier_DD4CD", RED, "identifier_DD4CD")]:
  add_line(key, ax, color, label)

# %%
plt.figure(figsize=(6, 16))
ax = plt.subplot(4, 1, 1)
for key, color, label in [ ("basictype_CD", BLUE, "basictype_CD"),
                           ("basictype_DD4CD", RED, "basictype_DD4CD")]:
  add_line(key, ax, color, label)

# %%
plt.figure(figsize=(6, 16))
ax = plt.subplot(4, 1, 1)
for key, color, label in [ ("boolean_CD", BLUE, "boolean_CD"),
                           ("boolean_DD4CD", RED, "boolean_DD4CD")]:
  add_line(key, ax, color, label)

# %%
plt.figure(figsize=(6, 16))
ax = plt.subplot(4, 1, 1)
for key, color, label in [ ("identifier_CD", BLUE, "identifier_CD"),
                           ("identifier_DD4CD", RED, "identifier_DD4CD")]:
  add_line(key, ax, color, label)
